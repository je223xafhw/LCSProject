# %%
import pandas as pd

data = [
    [(16, 32, 64), 0, 0.1, 32, (73.90, 75.46, 74.21)],
    [(16, 32, 64), 0, 0.1, 32, (50.04, 49.96, 51.15)],
    [(16, 32, 64), 0, 0.1, 128, (85.97, 82.77, 74.27)],
    [(16, 32, 64), 0, 0.005, 32, (87.57, 87.63, 87.61)],
    [(16, 32, 64), 0, 0.005, 64, (87.69, 87.68, 87.59)],
    [(16, 32, 64), 0, 0.005, 128, (87.68, 87.69, 87.75)],
    [(16, 32, 64), 0, 0.001, 32, (87.63, 87.53, 87.76)],
    [(16, 32, 64), 0, 0.001, 64, (87.65, 87.78, 87.79)],
    [(16, 32, 64), 0, 0.001, 128, (87.77, 87.65, 87.78)],
    [(16, 32, 64), 0.2, 0.1, 32, (73.62, 73.57, 73.88)],
    [(16, 32, 64), 0.2, 0.1, 64, (81.59, 73.57, 74.94)],
    [(16, 32, 64), 0.2, 0.1, 128, (82.85, 74.93, 74.27)],
    [(16, 32, 64), 0.2, 0.005, 32, (87.40, 87.35, 87.22)],
    [(16, 32, 64), 0.2, 0.005, 64, (87.03, 87.40, 87.59)],
    [(16, 32, 64), 0.2, 0.005, 128, (87.40, 87.49, 87.39)],
    [(16, 32, 64), 0.2, 0.001, 32, (87.10, 87.35, 87.38)],
    [(16, 32, 64), 0.2, 0.001, 64, (87.08, 87.37, 87.59)],
    [(16, 32, 64), 0.2, 0.001, 128, (87.20, 87.39, 87.52)]
]

df = pd.DataFrame(data, columns=['Nodes', 'Dropout Wahrscheinlichkeit', 'Lernrate', 'Batch Größe', 'Genauigkeit'])

# Display the DataFrame
# print(df)

# %%
if False:
    for r in df.iterrows():
        r = r[1]
        for i, n in enumerate(r.Nodes):
            print(f"[{n}, {r['Dropout Wahrscheinlichkeit']}, {r['Lernrate']}, {r['Batch Größe']}, {r['Genauigkeit'][i]}],")

# %%
data = [ [16, 0.0, 0.1, 32, 73.9], [32, 0.0, 0.1, 32, 75.46], [64, 0.0, 0.1, 32, 74.21], [16, 0.0, 0.1, 32, 50.04], [32, 0.0, 0.1, 32, 49.96], [64, 0.0, 0.1, 32, 51.15], [16, 0.0, 0.1, 128, 85.97], [32, 0.0, 0.1, 128, 82.77], [64, 0.0, 0.1, 128, 74.27], [16, 0.0, 0.005, 32, 87.57], [32, 0.0, 0.005, 32, 87.63], [64, 0.0, 0.005, 32, 87.61], [16, 0.0, 0.005, 64, 87.69], [32, 0.0, 0.005, 64, 87.68], [64, 0.0, 0.005, 64, 87.59], [16, 0.0, 0.005, 128, 87.68], [32, 0.0, 0.005, 128, 87.69], [64, 0.0, 0.005, 128, 87.75], [16, 0.0, 0.001, 32, 87.63], [32, 0.0, 0.001, 32, 87.53], [64, 0.0, 0.001, 32, 87.76], [16, 0.0, 0.001, 64, 87.65], [32, 0.0, 0.001, 64, 87.78], [64, 0.0, 0.001, 64, 87.79], [16, 0.0, 0.001, 128, 87.77], [32, 0.0, 0.001, 128, 87.65], [64, 0.0, 0.001, 128, 87.78], [16, 0.2, 0.1, 32, 73.62], [32, 0.2, 0.1, 32, 73.57], [64, 0.2, 0.1, 32, 73.88], [16, 0.2, 0.1, 64, 81.59], [32, 0.2, 0.1, 64, 73.57], [64, 0.2, 0.1, 64, 74.94], [16, 0.2, 0.1, 128, 82.85], [32, 0.2, 0.1, 128, 74.93], [64, 0.2, 0.1, 128, 74.27], [16, 0.2, 0.005, 32, 87.4], [32, 0.2, 0.005, 32, 87.35], [64, 0.2, 0.005, 32, 87.22], [16, 0.2, 0.005, 64, 87.03], [32, 0.2, 0.005, 64, 87.4], [64, 0.2, 0.005, 64, 87.59], [16, 0.2, 0.005, 128, 87.4], [32, 0.2, 0.005, 128, 87.49], [64, 0.2, 0.005, 128, 87.39], [16, 0.2, 0.001, 32, 87.1], [32, 0.2, 0.001, 32, 87.35], [64, 0.2, 0.001, 32, 87.38], [16, 0.2, 0.001, 64, 87.08], [32, 0.2, 0.001, 64, 87.37], [64, 0.2, 0.001, 64, 87.59], [16, 0.2, 0.001, 128, 87.2], [32, 0.2, 0.001, 128, 87.39], [64, 0.2, 0.001, 128, 87.52], ]
df = pd.DataFrame(data, columns=['Nodes', 'Dropout Wahrscheinlichkeit', 'Lernrate', 'Batch Größe', 'Genauigkeit'])

# %%
df.plot.scatter(x='Dropout Wahrscheinlichkeit',  y='Genauigkeit', c='Nodes', cmap='cividis')
# df.plot.scatter(x='Nodes',  y='Lernrate',                   c='Genauigkeit', cmap='cividis')
# df.plot.scatter(x='Nodes',  y='Batch Größe',                c='Genauigkeit', cmap='cividis')
# Out:
# <Axes: xlabel='Dropout Wahrscheinlichkeit', ylabel='Genauigkeit'>
